# %%
# Celsius to fahrenheit

# %%
import pandas as pd

data = pd.read_csv('./data/data.csv')

# %%
# define data X and y

X = data['celsius'].values
y = data['fahrenheit'].values

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(units=1) # the farhenheit value
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.1), 
    loss='mean_squared_error'
)

# %%
training = model.fit(X, y, epochs=1000, verbose=0) # verbose=0 to hide the output

# %%
import matplotlib.pyplot as plt

plt.xlabel("Epochs")
plt.ylabel("Loss") 
plt.plot(training.history['loss'])

# %%
import numpy as np

c = np.array([1230])
prediction = model.predict(c)
print(f'{c[0]} celsius is {prediction[0][0]} fahrenheit')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1230 celsius is 2246.00048828125 fahrenheit

# %%
model.layers[0].get_weights()
# Out:
# [array([[1.8000004]], dtype=float32), array([31.999952], dtype=float32)]

# %% [markdown]
# ### Explanation
# The calculation is an approximate to the real calculation
# (celsius * 1.8) + 32 = fahrenheit
